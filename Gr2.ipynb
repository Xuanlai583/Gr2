# %% [markdown]
# <a href="https://colab.research.google.com/github/Xuanlai583/Gr2/blob/main/Gr2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Install packages**

# %%
# %%capture
# !pip install segmentation-models-pytorch
# !pip install torchinfo

# %% [markdown]
# # **2. Import libraries**

# %%
# Data handling
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# train test split
from sklearn.model_selection import train_test_split

# Torch
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn, optim
from torchinfo import summary
import segmentation_models_pytorch as smp
from torchvision import transforms

# os
import os

# Path
from pathlib import Path

# tqdm
from tqdm.auto import tqdm

# warnings
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **3. Load data**

# %%
# Total Images
IMAGE_PATH = Path("/content/drive/MyDrive/Dataset/images")
IMAGE_PATH_LIST = list(IMAGE_PATH.glob("*.png"))
IMAGE_PATH_LIST = sorted(IMAGE_PATH_LIST)

print(f'Total Images = {len(IMAGE_PATH_LIST)}')
# Out:
# Total Images = 31

# %%
# Total Masks
MASK_PATH = Path("/content/drive/MyDrive/Dataset/masks")
MASK_PATH_LIST = list(MASK_PATH.glob("*.png"))
MASK_PATH_LIST = sorted(MASK_PATH_LIST)

print(f'Total Masks = {len(MASK_PATH_LIST)}')
# Out:
# Total Masks = 31

# %%
# We view some images with their respective masks.
fig,ax = plt.subplots(nrows = 5, ncols = 2, figsize = (9,15))

for i,(img_path, mk_path) in enumerate(zip(IMAGE_PATH_LIST, MASK_PATH_LIST)):
    if i>4:
        break

    img_bgr = cv2.imread(str(img_path))
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    ax[i,0].imshow(img_bgr)
    ax[i,0].axis('off')
    ax[i,0].set_title(f'Shape: {img_rgb.shape}')

    mask_bgr = cv2.imread(str(mk_path))
    mask_rgb = cv2.cvtColor(mask_bgr, cv2.COLOR_BGR2RGB)
    ax[i,1].imshow(mask_rgb)
    ax[i,1].axis('off')
    ax[i,1].set_title(f'Shape: {mask_rgb.shape}')

fig.tight_layout()
fig.show()

# %% [markdown]
# # **4. Preprocessing**

# %% [markdown]
# We create a **dataframe** where we store the **image paths** and their respective **mask**.

# %%
images_paths = [None] * len(IMAGE_PATH_LIST)
masks_paths = [None] * len(MASK_PATH_LIST)

for i,(img_path, mask_path) in enumerate(zip(IMAGE_PATH_LIST, MASK_PATH_LIST)):
    images_paths[i] = img_path
    masks_paths[i] = mask_path

data = pd.DataFrame({'Image':images_paths, 'Mask':masks_paths})
data.head()
# Out:
#                                           Image  \
# 0   /content/drive/MyDrive/Dataset/images/0.png
# 1   /content/drive/MyDrive/Dataset/images/1.png
# 2  /content/drive/MyDrive/Dataset/images/10.png
# 3  /content/drive/MyDrive/Dataset/images/11.png
# 4  /content/drive/MyDrive/Dataset/images/12.png
#
#                                           Mask
# 0   /content/drive/MyDrive/Dataset/masks/0.png
# 1   /content/drive/MyDrive/Dataset/masks/1.png
# 2  /content/drive/MyDrive/Dataset/masks/10.png
# 3  /content/drive/MyDrive/Dataset/masks/11.png
# 4  /content/drive/MyDrive/Dataset/masks/12.png

# %% [markdown]
# We divide our dataframe into 3 data sets:
# - **train = 70%**
# - **validation = 15%**
# - **test = 15%**

# %%
SEED = 42

data_train, data_rest = train_test_split(data,
                                         test_size = 0.3,
                                         random_state = SEED)

data_val, data_test = train_test_split(data_rest,
                                       test_size = 0.5,
                                       random_state = SEED)

# %% [markdown]
# We create a **dictionary** where we have stored the **color** and its respective **id** of each class.

# %%
color2id = {(184, 61, 245): 0, # #b83df5: backgroud
            (255, 53, 94):1, # #ff355e: road_sign
            (255, 204, 51):2, # #ffcc33: car
            (221, 255, 51):3, # #ddff33: marking
            (61,61, 245):4} # #3d3df5: road_surface

# %%
# We define a function to create an array of id's that will help us calculate the metrics and the loss.
def mapping_color(img:Image, color2id:dict):

    image = np.array(img)

    height,width,_ = image.shape
    output_matrix = np.full(shape = (height, width), fill_value = -1, dtype = np.int32)

    for h in range(height):
        for w in range(width):
            color_pixel = tuple(image[h,w,:])

            if color_pixel in color2id:
                output_matrix[h,w] = color2id[color_pixel]


    return output_matrix

# %% [markdown]
# Now we create our **Dataset's** and then **DataLoader's**.

# %% [markdown]
# - **Dataset**

# %%
class CustomDataset(Dataset):
    def __init__(self, data:pd.DataFrame, color2id:dict, image_transforms, mask_transforms):
        self.data = data
        self.color2id = color2id
        self.image_transforms = image_transforms
        self.mask_transforms = mask_transforms

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):

        image_path = data.iloc[idx, 0]
        image = Image.open(image_path).convert("RGB")
        image = self.image_transforms(image)

        mask_path = data.iloc[idx, 1]
        mask = Image.open(mask_path).convert("RGB")
        mask = self.mask_transforms(mask)
        mask = mapping_color(mask, self.color2id)

        return image, mask

# %%
RESIZE = (512, 512)

image_transforms = transforms.Compose([transforms.Resize(RESIZE),
                                       transforms.ToTensor()])

mask_transforms = transforms.Compose([transforms.Resize(RESIZE)])

# %%
train_dataset = CustomDataset(data_train,
                              color2id,
                              image_transforms,
                              mask_transforms)

val_dataset = CustomDataset(data_val,
                            color2id,
                            image_transforms,
                            mask_transforms)

# %% [markdown]
# - **DataLoader**

# %%
BATCH_SIZE = 1
NUM_WORKERS = os.cpu_count()

train_dataloader = DataLoader(dataset = train_dataset,
                              batch_size = BATCH_SIZE,
                              shuffle = True,
                              num_workers = NUM_WORKERS)

val_dataloader = DataLoader(dataset = val_dataset,
                            batch_size = 1,
                            shuffle = True,
                            num_workers = NUM_WORKERS)

# %%
# We visualize the dimensions of a batch.
batch_images, batch_masks = next(iter(train_dataloader))

batch_images.shape, batch_masks.shape
# Out:
# (torch.Size([1, 3, 512, 512]), torch.Size([1, 512, 512]))

# %% [markdown]
# # **5. Model**

# %%
# GPU
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
DEVICE
# Out:
# 'cuda'

# %%
# Define Model
model = smp.Unet(classes = 5)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 327MB/s]

# %%
# We visualize the architecture of our model.
summary(model = model,
        col_width = 17,
        input_size = [1,3,512,512],
        col_names = ['input_size','output_size','num_params','trainable'],
        row_settings = ['var_names'])
# Out:
# ======================================================================================================================
# Layer (type (var_name))                            Input Shape       Output Shape      Param #           Trainable
# ======================================================================================================================
# Unet (Unet)                                        [1, 3, 512, 512]  [1, 5, 512, 512]  --                True
# ├─ResNetEncoder (encoder)                          [1, 3, 512, 512]  [1, 3, 512, 512]  --                True
# │    └─Conv2d (conv1)                              [1, 3, 512, 512]  [1, 64, 256, 256] 9,408             True
# │    └─BatchNorm2d (bn1)                           [1, 64, 256, 256] [1, 64, 256, 256] 128               True
# │    └─ReLU (relu)                                 [1, 64, 256, 256] [1, 64, 256, 256] --                --
# │    └─MaxPool2d (maxpool)                         [1, 64, 256, 256] [1, 64, 128, 128] --                --
# │    └─Sequential (layer1)                         [1, 64, 128, 128] [1, 64, 128, 128] --                True
# │    │    └─BasicBlock (0)                         [1, 64, 128, 128] [1, 64, 128, 128] 73,984            True
# │    │    └─BasicBlock (1)                         [1, 64, 128, 128] [1, 64, 128, 128] 73,984            True
# │    │    └─BasicBlock (2)                         [1, 64, 128, 128] [1, 64, 128, 128] 73,984            True
# │    └─Sequential (layer2)                         [1, 64, 128, 128] [1, 128, 64, 64]  --                True
# │    │    └─BasicBlock (0)                         [1, 64, 128, 128] [1, 128, 64, 64]  230,144           True
# │    │    └─BasicBlock (1)                         [1, 128, 64, 64]  [1, 128, 64, 64]  295,424           True
# │    │    └─BasicBlock (2)                         [1, 128, 64, 64]  [1, 128, 64, 64]  295,424           True
# │    │    └─BasicBlock (3)                         [1, 128, 64, 64]  [1, 128, 64, 64]  295,424           True
# │    └─Sequential (layer3)                         [1, 128, 64, 64]  [1, 256, 32, 32]  --                True
# │    │    └─BasicBlock (0)                         [1, 128, 64, 64]  [1, 256, 32, 32]  919,040           True
# │    │    └─BasicBlock (1)                         [1, 256, 32, 32]  [1, 256, 32, 32]  1,180,672         True
# │    │    └─BasicBlock (2)                         [1, 256, 32, 32]  [1, 256, 32, 32]  1,180,672         True
# │    │    └─BasicBlock (3)                         [1, 256, 32, 32]  [1, 256, 32, 32]  1,180,672         True
# │    │    └─BasicBlock (4)                         [1, 256, 32, 32]  [1, 256, 32, 32]  1,180,672         True
# │    │    └─BasicBlock (5)                         [1, 256, 32, 32]  [1, 256, 32, 32]  1,180,672         True
# │    └─Sequential (layer4)                         [1, 256, 32, 32]  [1, 512, 16, 16]  --                True
# │    │    └─BasicBlock (0)                         [1, 256, 32, 32]  [1, 512, 16, 16]  3,673,088         True
# │    │    └─BasicBlock (1)                         [1, 512, 16, 16]  [1, 512, 16, 16]  4,720,640         True
# │    │    └─BasicBlock (2)                         [1, 512, 16, 16]  [1, 512, 16, 16]  4,720,640         True
# ├─UnetDecoder (decoder)                            [1, 3, 512, 512]  [1, 16, 512, 512] --                True
# │    └─Identity (center)                           [1, 512, 16, 16]  [1, 512, 16, 16]  --                --
# │    └─ModuleList (blocks)                         --                --                --                True
# │    │    └─DecoderBlock (0)                       [1, 512, 16, 16]  [1, 256, 32, 32]  2,360,320         True
# │    │    └─DecoderBlock (1)                       [1, 256, 32, 32]  [1, 128, 64, 64]  590,336           True
# │    │    └─DecoderBlock (2)                       [1, 128, 64, 64]  [1, 64, 128, 128] 147,712           True
# │    │    └─DecoderBlock (3)                       [1, 64, 128, 128] [1, 32, 256, 256] 46,208            True
# │    │    └─DecoderBlock (4)                       [1, 32, 256, 256] [1, 16, 512, 512] 6,976             True
# ├─SegmentationHead (segmentation_head)             [1, 16, 512, 512] [1, 5, 512, 512]  --                True
# │    └─Conv2d (0)                                  [1, 16, 512, 512] [1, 5, 512, 512]  725               True
# │    └─Identity (1)                                [1, 5, 512, 512]  [1, 5, 512, 512]  --                --
# │    └─Activation (2)                              [1, 5, 512, 512]  [1, 5, 512, 512]  --                --
# │    │    └─Identity (activation)                  [1, 5, 512, 512]  [1, 5, 512, 512]  --                --
# ======================================================================================================================
# Total params: 24,436,949
# Trainable params: 24,436,949
# Non-trainable params: 0
# Total mult-adds (G): 31.41
# ======================================================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 583.01
# Params size (MB): 97.75
# Estimated Total Size (MB): 683.90
# ======================================================================================================================

# %%
# We freeze the encoder layer.
for param in model.encoder.parameters():
    param.requires_grad = False

# %%
# We see again if the encoder layer freezes.
summary(model = model,
        col_width = 17,
        input_size = [1,3,512,512],
        col_names = ['input_size','output_size','num_params','trainable'],
        row_settings = ['var_names'])
# Out:
# ======================================================================================================================
# Layer (type (var_name))                            Input Shape       Output Shape      Param #           Trainable
# ======================================================================================================================
# Unet (Unet)                                        [1, 3, 512, 512]  [1, 5, 512, 512]  --                Partial
# ├─ResNetEncoder (encoder)                          [1, 3, 512, 512]  [1, 3, 512, 512]  --                False
# │    └─Conv2d (conv1)                              [1, 3, 512, 512]  [1, 64, 256, 256] (9,408)           False
# │    └─BatchNorm2d (bn1)                           [1, 64, 256, 256] [1, 64, 256, 256] (128)             False
# │    └─ReLU (relu)                                 [1, 64, 256, 256] [1, 64, 256, 256] --                --
# │    └─MaxPool2d (maxpool)                         [1, 64, 256, 256] [1, 64, 128, 128] --                --
# │    └─Sequential (layer1)                         [1, 64, 128, 128] [1, 64, 128, 128] --                False
# │    │    └─BasicBlock (0)                         [1, 64, 128, 128] [1, 64, 128, 128] (73,984)          False
# │    │    └─BasicBlock (1)                         [1, 64, 128, 128] [1, 64, 128, 128] (73,984)          False
# │    │    └─BasicBlock (2)                         [1, 64, 128, 128] [1, 64, 128, 128] (73,984)          False
# │    └─Sequential (layer2)                         [1, 64, 128, 128] [1, 128, 64, 64]  --                False
# │    │    └─BasicBlock (0)                         [1, 64, 128, 128] [1, 128, 64, 64]  (230,144)         False
# │    │    └─BasicBlock (1)                         [1, 128, 64, 64]  [1, 128, 64, 64]  (295,424)         False
# │    │    └─BasicBlock (2)                         [1, 128, 64, 64]  [1, 128, 64, 64]  (295,424)         False
# │    │    └─BasicBlock (3)                         [1, 128, 64, 64]  [1, 128, 64, 64]  (295,424)         False
# │    └─Sequential (layer3)                         [1, 128, 64, 64]  [1, 256, 32, 32]  --                False
# │    │    └─BasicBlock (0)                         [1, 128, 64, 64]  [1, 256, 32, 32]  (919,040)         False
# │    │    └─BasicBlock (1)                         [1, 256, 32, 32]  [1, 256, 32, 32]  (1,180,672)       False
# │    │    └─BasicBlock (2)                         [1, 256, 32, 32]  [1, 256, 32, 32]  (1,180,672)       False
# │    │    └─BasicBlock (3)                         [1, 256, 32, 32]  [1, 256, 32, 32]  (1,180,672)       False
# │    │    └─BasicBlock (4)                         [1, 256, 32, 32]  [1, 256, 32, 32]  (1,180,672)       False
# │    │    └─BasicBlock (5)                         [1, 256, 32, 32]  [1, 256, 32, 32]  (1,180,672)       False
# │    └─Sequential (layer4)                         [1, 256, 32, 32]  [1, 512, 16, 16]  --                False
# │    │    └─BasicBlock (0)                         [1, 256, 32, 32]  [1, 512, 16, 16]  (3,673,088)       False
# │    │    └─BasicBlock (1)                         [1, 512, 16, 16]  [1, 512, 16, 16]  (4,720,640)       False
# │    │    └─BasicBlock (2)                         [1, 512, 16, 16]  [1, 512, 16, 16]  (4,720,640)       False
# ├─UnetDecoder (decoder)                            [1, 3, 512, 512]  [1, 16, 512, 512] --                True
# │    └─Identity (center)                           [1, 512, 16, 16]  [1, 512, 16, 16]  --                --
# │    └─ModuleList (blocks)                         --                --                --                True
# │    │    └─DecoderBlock (0)                       [1, 512, 16, 16]  [1, 256, 32, 32]  2,360,320         True
# │    │    └─DecoderBlock (1)                       [1, 256, 32, 32]  [1, 128, 64, 64]  590,336           True
# │    │    └─DecoderBlock (2)                       [1, 128, 64, 64]  [1, 64, 128, 128] 147,712           True
# │    │    └─DecoderBlock (3)                       [1, 64, 128, 128] [1, 32, 256, 256] 46,208            True
# │    │    └─DecoderBlock (4)                       [1, 32, 256, 256] [1, 16, 512, 512] 6,976             True
# ├─SegmentationHead (segmentation_head)             [1, 16, 512, 512] [1, 5, 512, 512]  --                True
# │    └─Conv2d (0)                                  [1, 16, 512, 512] [1, 5, 512, 512]  725               True
# │    └─Identity (1)                                [1, 5, 512, 512]  [1, 5, 512, 512]  --                --
# │    └─Activation (2)                              [1, 5, 512, 512]  [1, 5, 512, 512]  --                --
# │    │    └─Identity (activation)                  [1, 5, 512, 512]  [1, 5, 512, 512]  --                --
# ======================================================================================================================
# Total params: 24,436,949
# Trainable params: 3,152,277
# Non-trainable params: 21,284,672
# Total mult-adds (G): 31.41
# ======================================================================================================================
# Input size (MB): 3.15
# Forward/backward pass size (MB): 583.01
# Params size (MB): 97.75
# Estimated Total Size (MB): 683.90
# ======================================================================================================================

# %% [markdown]
# We define the **loss function** and the **optimizer**.

# %%
loss_fn = smp.losses.DiceLoss(mode = "multiclass", classes = 5, ignore_index = -1)
optimizer = optim.Adam(model.parameters(), lr = 0.01, weight_decay = 0.0001)

# %% [markdown]
# We define some functions to execute the training and another to make the predictions on new data:
#
# - **EarlyStopping**
# - **train_step**
# - **val_step**
# - **predictions**

# %%
class EarlyStopping:
    def __init__(self, patience:int = 5, delta:float = 0.0001, path = "best_model.pth"):
        self.patience = patience
        self.delta = delta
        self.path = path
        self.best_score = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss, model):
        if self.best_score is None:
            self.best_score = val_loss
            self.save_checkpoint(model)

        elif val_loss > self.best_score + self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

        else:
            self.best_score = val_loss
            self.save_checkpoint(model)
            self.counter = 0

    def save_checkpoint(self, model):
        torch.save(model.state_dict(), self.path)

# %%
# Define EarlyStopping
early_stopping = EarlyStopping(patience = 20, delta = 0.)

# %%
def train_step(model:torch.nn.Module, dataloader:torch.utils.data.DataLoader,
               loss_fn:smp.losses, optimizer:torch.optim.Optimizer):

    model.train()

    train_loss = 0.
    train_iou = 0.

    for batch,(X,y) in enumerate(dataloader):
        X = X.to(device = DEVICE, dtype = torch.float32)
        y = y.to(device = DEVICE, dtype = torch.long)

        optimizer.zero_grad()

        pred_logit = model(X)
        loss = loss_fn(pred_logit, y)
        train_loss = loss.item()

        loss.backward()
        optimizer.step()

        pred_prob = pred_logit.softmax(dim = 1)
        pred_class = pred_prob.argmax(dim = 1)

        tp,fp,fn,tn = smp.metrics.get_stats(output = pred_class.detach().cpu().long(),
                                            target = y.cpu(),
                                            mode = "multiclass",
                                            ignore_index = -1,
                                            num_classes = 5)

        train_iou += smp.metrics.iou_score(tp, fp, fn, tn, reduction = "micro")

    train_loss = train_loss / len(dataloader)
    train_iou = train_iou / len(dataloader)

    return train_loss, train_iou

# %%
def val_step(model:torch.nn.Module, dataloader:torch.utils.data.DataLoader,
             loss_fn:smp.losses):

    model.eval()

    val_loss = 0.
    val_iou = 0.

    with torch.inference_mode():

        for batch,(X,y) in enumerate(dataloader):
            X = X.to(device = DEVICE, dtype = torch.float32)
            y = y.to(device = DEVICE, dtype = torch.long)

            pred_logit = model(X)
            loss = loss_fn(pred_logit, y)
            val_loss = loss.item()

            pred_prob = pred_logit.softmax(dim = 1)
            pred_class = pred_prob.argmax(dim = 1)

            tp,fp,fn,tn = smp.metrics.get_stats(output = pred_class.detach().cpu().long(),
                                                target = y.cpu(),
                                                mode = "multiclass",
                                                ignore_index = -1,
                                                num_classes = 5)

            val_iou += smp.metrics.iou_score(tp, fp, fn, tn, reduction = "micro")


    val_loss = val_loss / len(dataloader)
    val_iou = val_iou / len(dataloader)

    return val_loss, val_iou

# %%
def train(model:torch.nn.Module, train_dataloader:torch.utils.data.DataLoader,
          val_dataloader:torch.utils.data.DataLoader, loss_fn:torch.nn.Module, optimizer:torch.optim.Optimizer,
          early_stopping, epochs:int = 10):

    results = {'train_loss':[], 'train_iou':[], 'val_loss':[], 'val_iou':[]}

    for epoch in tqdm(range(epochs)):
        train_loss, train_iou = train_step(model = model,
                                           dataloader = train_dataloader,
                                           loss_fn = loss_fn,
                                           optimizer = optimizer)

        val_loss, val_iou = val_step(model = model,
                                     dataloader = val_dataloader,
                                     loss_fn = loss_fn)

        print(f'Epoch: {epoch + 1} | ',
              f'Train Loss: {train_loss:.4f} | ',
              f'Train IOU: {train_iou:.4f} | ',
              f'Val Loss: {val_loss:.4f} | ',
              f'Val IOU: {val_iou:.4f}')


        early_stopping(val_loss, model)

        if early_stopping.early_stop == True:
            print("Early Stopping!!")
            break

        results['train_loss'].append(train_loss)
        results['train_iou'].append(train_iou)
        results['val_loss'].append(val_loss)
        results['val_iou'].append(val_iou)

    return results

# %%
# Training!!!
EPOCHS = 100

torch.cuda.manual_seed(SEED)
torch.manual_seed(SEED)

RESULTS = train(model.to(device = DEVICE),
                train_dataloader,
                val_dataloader,
                loss_fn,
                optimizer,
                early_stopping,
                EPOCHS)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 |  Train Loss: 0.0270 |  Train IOU: 0.8097 |  Val Loss: 0.1373 |  Val IOU: 0.6156
# Epoch: 2 |  Train Loss: 0.0171 |  Train IOU: 0.9347 |  Val Loss: 0.0688 |  Val IOU: 0.9090
# Epoch: 3 |  Train Loss: 0.0193 |  Train IOU: 0.9387 |  Val Loss: 0.1149 |  Val IOU: 0.3651
# Epoch: 4 |  Train Loss: 0.0121 |  Train IOU: 0.9092 |  Val Loss: 0.0967 |  Val IOU: 0.4705
# Epoch: 5 |  Train Loss: 0.0117 |  Train IOU: 0.9401 |  Val Loss: 0.0338 |  Val IOU: 0.9639
# Epoch: 6 |  Train Loss: 0.0044 |  Train IOU: 0.9535 |  Val Loss: 0.0248 |  Val IOU: 0.9701
# Epoch: 7 |  Train Loss: 0.0065 |  Train IOU: 0.9401 |  Val Loss: 0.0600 |  Val IOU: 0.9365
# Epoch: 8 |  Train Loss: 0.0054 |  Train IOU: 0.9517 |  Val Loss: 0.0244 |  Val IOU: 0.9760
# Epoch: 9 |  Train Loss: 0.0135 |  Train IOU: 0.9573 |  Val Loss: 0.0312 |  Val IOU: 0.9598
# Epoch: 10 |  Train Loss: 0.0071 |  Train IOU: 0.9495 |  Val Loss: 0.0254 |  Val IOU: 0.9690
# Epoch: 11 |  Train Loss: 0.0109 |  Train IOU: 0.9589 |  Val Loss: 0.0173 |  Val IOU: 0.9661
# Epoch: 12 |  Train Loss: 0.0104 |  Train IOU: 0.9557 |  Val Loss: 0.0169 |  Val IOU: 0.9779
# Epoch: 13 |  Train Loss: 0.0057 |  Train IOU: 0.9410 |  Val Loss: 0.0258 |  Val IOU: 0.9356
# Epoch: 14 |  Train Loss: 0.0037 |  Train IOU: 0.9330 |  Val Loss: 0.0098 |  Val IOU: 0.9819
# Epoch: 15 |  Train Loss: 0.0139 |  Train IOU: 0.8911 |  Val Loss: 0.0179 |  Val IOU: 0.9648
# Epoch: 16 |  Train Loss: 0.0084 |  Train IOU: 0.9245 |  Val Loss: 0.0209 |  Val IOU: 0.9620
# Epoch: 17 |  Train Loss: 0.0030 |  Train IOU: 0.9404 |  Val Loss: 0.0300 |  Val IOU: 0.9714
# Epoch: 18 |  Train Loss: 0.0073 |  Train IOU: 0.9574 |  Val Loss: 0.0208 |  Val IOU: 0.9737
# Epoch: 19 |  Train Loss: 0.0015 |  Train IOU: 0.9621 |  Val Loss: 0.0180 |  Val IOU: 0.9680
# Epoch: 20 |  Train Loss: 0.0043 |  Train IOU: 0.9442 |  Val Loss: 0.0140 |  Val IOU: 0.9718
# Epoch: 21 |  Train Loss: 0.0055 |  Train IOU: 0.9607 |  Val Loss: 0.0137 |  Val IOU: 0.9784
# Epoch: 22 |  Train Loss: 0.0110 |  Train IOU: 0.9672 |  Val Loss: 0.0143 |  Val IOU: 0.9539
# Epoch: 23 |  Train Loss: 0.0096 |  Train IOU: 0.9689 |  Val Loss: 0.0364 |  Val IOU: 0.9666
# Epoch: 24 |  Train Loss: 0.0026 |  Train IOU: 0.9749 |  Val Loss: 0.0152 |  Val IOU: 0.9729
# Epoch: 25 |  Train Loss: 0.0109 |  Train IOU: 0.9767 |  Val Loss: 0.1817 |  Val IOU: 0.1407
# Epoch: 26 |  Train Loss: 0.0037 |  Train IOU: 0.8915 |  Val Loss: 0.0697 |  Val IOU: 0.6420
# Epoch: 27 |  Train Loss: 0.0094 |  Train IOU: 0.9366 |  Val Loss: 0.0274 |  Val IOU: 0.9744
# Epoch: 28 |  Train Loss: 0.0087 |  Train IOU: 0.9620 |  Val Loss: 0.0283 |  Val IOU: 0.9743
# Epoch: 29 |  Train Loss: 0.0096 |  Train IOU: 0.9550 |  Val Loss: 0.0123 |  Val IOU: 0.9745
# Epoch: 30 |  Train Loss: 0.0029 |  Train IOU: 0.9659 |  Val Loss: 0.0100 |  Val IOU: 0.9711
# Epoch: 31 |  Train Loss: 0.0060 |  Train IOU: 0.9688 |  Val Loss: 0.0096 |  Val IOU: 0.9806
# Epoch: 32 |  Train Loss: 0.0021 |  Train IOU: 0.9106 |  Val Loss: 0.0080 |  Val IOU: 0.9798
# Epoch: 33 |  Train Loss: 0.0054 |  Train IOU: 0.9709 |  Val Loss: 0.0116 |  Val IOU: 0.9755
# Epoch: 34 |  Train Loss: 0.0023 |  Train IOU: 0.9707 |  Val Loss: 0.0081 |  Val IOU: 0.9845
# Epoch: 35 |  Train Loss: 0.0100 |  Train IOU: 0.9770 |  Val Loss: 0.0134 |  Val IOU: 0.9748
# Epoch: 36 |  Train Loss: 0.0025 |  Train IOU: 0.9780 |  Val Loss: 0.0089 |  Val IOU: 0.9789
# Epoch: 37 |  Train Loss: 0.0033 |  Train IOU: 0.9753 |  Val Loss: 0.0113 |  Val IOU: 0.9796
# Epoch: 38 |  Train Loss: 0.0015 |  Train IOU: 0.9806 |  Val Loss: 0.0102 |  Val IOU: 0.9783
# Epoch: 39 |  Train Loss: 0.0047 |  Train IOU: 0.9803 |  Val Loss: 0.0099 |  Val IOU: 0.9818
# Epoch: 40 |  Train Loss: 0.0035 |  Train IOU: 0.9819 |  Val Loss: 0.0058 |  Val IOU: 0.9856
# Epoch: 41 |  Train Loss: 0.0020 |  Train IOU: 0.9825 |  Val Loss: 0.0168 |  Val IOU: 0.9782
# Epoch: 42 |  Train Loss: 0.0022 |  Train IOU: 0.9836 |  Val Loss: 0.0100 |  Val IOU: 0.9838
# Epoch: 43 |  Train Loss: 0.0010 |  Train IOU: 0.9852 |  Val Loss: 0.0117 |  Val IOU: 0.9760
# Epoch: 44 |  Train Loss: 0.0016 |  Train IOU: 0.9794 |  Val Loss: 0.0067 |  Val IOU: 0.9873
# Epoch: 45 |  Train Loss: 0.0026 |  Train IOU: 0.9819 |  Val Loss: 0.0054 |  Val IOU: 0.9878
# Epoch: 46 |  Train Loss: 0.0003 |  Train IOU: 0.9700 |  Val Loss: 0.0135 |  Val IOU: 0.9682
# Epoch: 47 |  Train Loss: 0.0030 |  Train IOU: 0.9767 |  Val Loss: 0.0075 |  Val IOU: 0.9830
# Epoch: 48 |  Train Loss: 0.0039 |  Train IOU: 0.9621 |  Val Loss: 0.0149 |  Val IOU: 0.9730
# Epoch: 49 |  Train Loss: 0.0027 |  Train IOU: 0.9767 |  Val Loss: 0.0081 |  Val IOU: 0.9834
# Epoch: 50 |  Train Loss: 0.0011 |  Train IOU: 0.9724 |  Val Loss: 0.0138 |  Val IOU: 0.9774
# Epoch: 51 |  Train Loss: 0.0028 |  Train IOU: 0.9748 |  Val Loss: 0.0106 |  Val IOU: 0.9763
# Epoch: 52 |  Train Loss: 0.0020 |  Train IOU: 0.9780 |  Val Loss: 0.0053 |  Val IOU: 0.9870
# Epoch: 53 |  Train Loss: 0.0158 |  Train IOU: 0.9801 |  Val Loss: 0.0567 |  Val IOU: 0.9048
# Epoch: 54 |  Train Loss: 0.0020 |  Train IOU: 0.9132 |  Val Loss: 0.0132 |  Val IOU: 0.9723
# Epoch: 55 |  Train Loss: 0.0034 |  Train IOU: 0.9788 |  Val Loss: 0.0094 |  Val IOU: 0.9822
# Epoch: 56 |  Train Loss: 0.0012 |  Train IOU: 0.9829 |  Val Loss: 0.0072 |  Val IOU: 0.9860
# Epoch: 57 |  Train Loss: 0.0020 |  Train IOU: 0.9845 |  Val Loss: 0.0097 |  Val IOU: 0.9855
# Epoch: 58 |  Train Loss: 0.0043 |  Train IOU: 0.9770 |  Val Loss: 0.0439 |  Val IOU: 0.9580
# Epoch: 59 |  Train Loss: 0.0023 |  Train IOU: 0.9710 |  Val Loss: 0.0284 |  Val IOU: 0.9717
# Epoch: 60 |  Train Loss: 0.0125 |  Train IOU: 0.9788 |  Val Loss: 0.0306 |  Val IOU: 0.9581
# Epoch: 61 |  Train Loss: 0.0008 |  Train IOU: 0.9820 |  Val Loss: 0.0155 |  Val IOU: 0.9828
# Epoch: 62 |  Train Loss: 0.0014 |  Train IOU: 0.9860 |  Val Loss: 0.0108 |  Val IOU: 0.9866
# Epoch: 63 |  Train Loss: 0.0022 |  Train IOU: 0.9877 |  Val Loss: 0.0097 |  Val IOU: 0.9853
# Epoch: 64 |  Train Loss: 0.0022 |  Train IOU: 0.9859 |  Val Loss: 0.0056 |  Val IOU: 0.9903
# Epoch: 65 |  Train Loss: 0.0004 |  Train IOU: 0.9874 |  Val Loss: 0.0123 |  Val IOU: 0.9898
# Epoch: 66 |  Train Loss: 0.0006 |  Train IOU: 0.9873 |  Val Loss: 0.0052 |  Val IOU: 0.9896
# Epoch: 67 |  Train Loss: 0.0012 |  Train IOU: 0.9878 |  Val Loss: 0.0188 |  Val IOU: 0.9801
# Epoch: 68 |  Train Loss: 0.0002 |  Train IOU: 0.9871 |  Val Loss: 0.0232 |  Val IOU: 0.9821
# Epoch: 69 |  Train Loss: 0.0019 |  Train IOU: 0.9884 |  Val Loss: 0.0178 |  Val IOU: 0.9826
# Epoch: 70 |  Train Loss: 0.0013 |  Train IOU: 0.9868 |  Val Loss: 0.0071 |  Val IOU: 0.9857
# Epoch: 71 |  Train Loss: 0.0003 |  Train IOU: 0.9877 |  Val Loss: 0.0118 |  Val IOU: 0.9883
# Epoch: 72 |  Train Loss: 0.0014 |  Train IOU: 0.9891 |  Val Loss: 0.0050 |  Val IOU: 0.9891
# Epoch: 73 |  Train Loss: 0.0006 |  Train IOU: 0.9893 |  Val Loss: 0.0059 |  Val IOU: 0.9896
# Epoch: 74 |  Train Loss: 0.0010 |  Train IOU: 0.9898 |  Val Loss: 0.0167 |  Val IOU: 0.9827
# Epoch: 75 |  Train Loss: 0.0014 |  Train IOU: 0.9899 |  Val Loss: 0.0128 |  Val IOU: 0.9889
# Epoch: 76 |  Train Loss: 0.0004 |  Train IOU: 0.9887 |  Val Loss: 0.0062 |  Val IOU: 0.9903
# Epoch: 77 |  Train Loss: 0.0010 |  Train IOU: 0.9893 |  Val Loss: 0.0097 |  Val IOU: 0.9840
# Epoch: 78 |  Train Loss: 0.0004 |  Train IOU: 0.9896 |  Val Loss: 0.0060 |  Val IOU: 0.9873
# Epoch: 79 |  Train Loss: 0.0010 |  Train IOU: 0.9884 |  Val Loss: 0.0079 |  Val IOU: 0.9854
# Epoch: 80 |  Train Loss: 0.0017 |  Train IOU: 0.9848 |  Val Loss: 0.0170 |  Val IOU: 0.9736
# Epoch: 81 |  Train Loss: 0.0013 |  Train IOU: 0.9857 |  Val Loss: 0.0045 |  Val IOU: 0.9893
# Epoch: 82 |  Train Loss: 0.0011 |  Train IOU: 0.9857 |  Val Loss: 0.0107 |  Val IOU: 0.9846
# Epoch: 83 |  Train Loss: 0.0043 |  Train IOU: 0.9810 |  Val Loss: 0.0072 |  Val IOU: 0.9832
# Epoch: 84 |  Train Loss: 0.0015 |  Train IOU: 0.9828 |  Val Loss: 0.0113 |  Val IOU: 0.9825
# Epoch: 85 |  Train Loss: 0.0012 |  Train IOU: 0.9833 |  Val Loss: 0.0064 |  Val IOU: 0.9866
# Epoch: 86 |  Train Loss: 0.0018 |  Train IOU: 0.9785 |  Val Loss: 0.0053 |  Val IOU: 0.9880
# Epoch: 87 |  Train Loss: 0.0018 |  Train IOU: 0.9849 |  Val Loss: 0.0058 |  Val IOU: 0.9868
# Epoch: 88 |  Train Loss: 0.0024 |  Train IOU: 0.9853 |  Val Loss: 0.0081 |  Val IOU: 0.9850
# Epoch: 89 |  Train Loss: 0.0012 |  Train IOU: 0.9886 |  Val Loss: 0.0084 |  Val IOU: 0.9866
# Epoch: 90 |  Train Loss: 0.0009 |  Train IOU: 0.9873 |  Val Loss: 0.0190 |  Val IOU: 0.9774
# Epoch: 91 |  Train Loss: 0.0014 |  Train IOU: 0.9787 |  Val Loss: 0.0352 |  Val IOU: 0.9201
# Epoch: 92 |  Train Loss: 0.0016 |  Train IOU: 0.9794 |  Val Loss: 0.0367 |  Val IOU: 0.9600
# Epoch: 93 |  Train Loss: 0.0058 |  Train IOU: 0.9586 |  Val Loss: 0.0287 |  Val IOU: 0.9486
# Epoch: 94 |  Train Loss: 0.0057 |  Train IOU: 0.9548 |  Val Loss: 0.0217 |  Val IOU: 0.9298
# Epoch: 95 |  Train Loss: 0.0023 |  Train IOU: 0.9597 |  Val Loss: 0.0126 |  Val IOU: 0.9757
# Epoch: 96 |  Train Loss: 0.0070 |  Train IOU: 0.9777 |  Val Loss: 0.0103 |  Val IOU: 0.9708
# Epoch: 97 |  Train Loss: 0.0033 |  Train IOU: 0.9826 |  Val Loss: 0.0062 |  Val IOU: 0.9872
# Epoch: 98 |  Train Loss: 0.0011 |  Train IOU: 0.9835 |  Val Loss: 0.0089 |  Val IOU: 0.9805
# Epoch: 99 |  Train Loss: 0.0015 |  Train IOU: 0.9847 |  Val Loss: 0.0110 |  Val IOU: 0.9857
# Epoch: 100 |  Train Loss: 0.0016 |  Train IOU: 0.9874 |  Val Loss: 0.0101 |  Val IOU: 0.9881

# %%
# We define a function to visualize the evolution of the metric and the loss during training.
def loss_and_metric_plot(results:dict):
    training_loss = results['train_loss']
    valid_loss = results['val_loss']

    training_iou = results['train_iou']
    valid_iou = results['val_iou']

    fig,axes = plt.subplots(nrows = 1, ncols = 2, figsize = (9,4))
    axes = axes.flat

    axes[0].plot(range(len(training_loss)), training_loss)
    axes[0].plot(range(len(valid_loss)), valid_loss)
    axes[0].set_xlabel("Epoch", fontsize = 12, fontweight = "bold", color = "black")
    axes[0].set_ylabel("Loss", fontsize = 12, fontweight = "bold", color = "black")
    axes[0].set_title("Dice Loss", fontsize = 14, fontweight = "bold", color = "blue")

    axes[1].plot(range(len(training_iou)), training_iou)
    axes[1].plot(range(len(valid_iou)), valid_iou)
    axes[1].set_xlabel("Epoch", fontsize = 12, fontweight = "bold", color = "black")
    axes[1].set_ylabel("score", fontsize = 12, fontweight = "bold", color = "black")
    axes[1].set_title("IOU", fontsize = 14, fontweight = "bold", color = "red")

    fig.tight_layout()
    fig.show()

# %%
loss_and_metric_plot(RESULTS)

# %% [markdown]
# # **6. Evaluation metric**

# %%
def predictions(test_dataloader:torch.utils.data.DataLoader, best_model:str):

    checkpoint = torch.load(best_model)

    loaded_model = smp.Unet(encoder_name = "resnet34", encoder_weights = None, classes = 5)

    loaded_model.load_state_dict(checkpoint)

    loaded_model.to(device = DEVICE)

    loaded_model.eval()

    pred_mask_test = []

    with torch.inference_mode():
        for X,_ in tqdm(test_dataloader):
            X = X.to(device = DEVICE, dtype = torch.float32)
            logit_mask = loaded_model(X)
            prob_mask = logit_mask.softmax(dim = 1)
            pred_mask = prob_mask.argmax(dim = 1)
            pred_mask_test.append(pred_mask.detach().cpu())

    pred_mask_test = torch.cat(pred_mask_test)

    return pred_mask_test

# %% [markdown]
# - **Predictions**

# %% [markdown]
# Just as we did with our training and validation data we are going to create our **Dataset** and **DataLoader** for our **test set**.

# %%
test_dataset = CustomDataset(data_test, color2id, image_transforms, mask_transforms)

test_dataloader = DataLoader(dataset = test_dataset,
                             batch_size = BATCH_SIZE,
                             shuffle = False)

# %%
pred_mask_test = predictions(test_dataloader, "./best_model.pth")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# We are going to create our tensors so we can plot later.
IMAGE_TEST = []
MASK_TEST = []

for img,mask in test_dataloader:
    IMAGE_TEST.append(img)
    MASK_TEST.append(mask)

IMAGE_TEST = torch.cat(IMAGE_TEST)

MASK_TEST = torch.cat(MASK_TEST)

# %% [markdown]
# - **IOU**

# %%
TP, FP, FN, TN = smp.metrics.get_stats(output = pred_mask_test.long(),
                                       target = MASK_TEST.long(),
                                       mode = "multiclass",
                                       ignore_index = -1,
                                       num_classes = 5)

# %%
iou_test = smp.metrics.iou_score(TP, FP, FN, TN, reduction = "micro")
print(f'IOU Test = {iou_test:.4f}')
# Out:
# IOU Test = 0.9893

# %% [markdown]
# # **7. Display mask test**

# %% [markdown]
# Now we want to visualize the predictions versus the actual masks, for this we are going to create a **dictionary** called **`id2color` to obtain the color according to the `id`**.

# %%
id2color = {0: (184, 61, 245), # background
            1: (255, 53, 94), # road_sign
            2: (255, 204, 51), # car
            3: (221, 255, 51), # marking
            4: (61,61, 245)} # road_surface

# %% [markdown]
# **Now we are going to transform the matrices that contained the id's to the predicted mask with their respective colors.**

# %%
total_mask_output = []

for i,mask_pred in enumerate(pred_mask_test):

    # We extract the height and width of the mask.
    height,width = mask_pred.shape

    # We are going to create a Boolean array to filter the values -1, which is that id that does not belong to any class.
    mask_original = MASK_TEST[i]
    ignore = mask_original == -1 # id: -1

    mask_predicted = torch.where(ignore, -1, mask_pred)
    mask_zeros = torch.zeros(size = (height, width, 3), dtype = torch.uint8)

    for h in range(height):
        for w in range(width):
            idcolor = int(mask_predicted[h,w])

            if idcolor in id2color:
                mask_zeros[h,w,:] = torch.tensor(id2color[idcolor])

    total_mask_output.append(mask_zeros)

# %% [markdown]
# **We are going to do the same for the real masks**.

# %%
total_mask_test = []

for mask_tst in MASK_TEST:

    # Extraemos el height y width de la máscara.
    height,width = mask_tst.shape

    mask_zeros = torch.zeros(size = (height, width, 3), dtype = torch.uint8)

    for h in range(height):
        for w in range(width):
            idcolor = int(mask_tst[h,w])

            if idcolor in id2color:
                mask_zeros[h,w,:] = torch.tensor(id2color[idcolor])

    total_mask_test.append(mask_zeros)

# %%
# Finally, we visualize the predicted mask and the actual mask.
fig, ax = plt.subplots(nrows = 5, ncols = 2, figsize = (8,20))

for i,(mk_out,mk_test) in enumerate(zip(total_mask_output, total_mask_test)):

    mask_test = mk_test.numpy()
    ax[i,0].imshow(mask_test)
    ax[i,0].set_title("Mask Original", fontsize = 12, fontweight = "bold", color = "red")
    ax[i,0].axis('off')

    mask_out = mk_out.numpy()
    ax[i,1].imshow(mask_out)
    ax[i,1].set_title("Mask Predicted", fontsize = 12, fontweight = "bold", color = "green")
    ax[i,1].axis('off')

fig.tight_layout()
fig.show()
